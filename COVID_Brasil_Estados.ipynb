# %% [markdown]
# <a href="https://colab.research.google.com/github/leomaranhao/COVID-19/blob/master/COVID_Brasil_Estados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import pandas.io.formats.format as pf
import datetime

# %%
df = pd.read_csv('https://brasil.io/dataset/covid19/caso?format=csv')

estados = df.loc[df.place_type=='state',['date','state','confirmed','deaths','is_last', 'estimated_population_2019']]

# %%
ultimas = estados.loc[estados.is_last==True, :]
ultimas.index = ultimas['state']
dataAtual = ultimas.iloc[0,0]
ultimas = ultimas.iloc[:, [2,3,5]]

ultimas.index.names = ['Estados']
ultimas.columns = ['Casos', 'Mortes', 'População 2019']

ultimas['Mortalidade'] = ultimas['Mortes']/ultimas['Casos'] * 100
ultimas['Casos/100 mil habitantes'] = ultimas['Casos'] / ultimas['População 2019'] * 100000

styles = [
    dict(selector="table", props=[("border-collapse", "collapse")]),
    dict(selector="th", props=[("text-align", "center"),
                               ("width", "15%")]),
    dict(selector="td", props=[("border", "1px solid black"),
                               #("width", "10%"),
                               ("text-align", "right")])
]

html = (ultimas.style.set_table_styles(styles)
          .format({'Casos' : '{0:,.0f}'})
          .format({'Mortes' : '{0:,.0f}'})
          .format({'População 2019' : '{0:,.0f}'})
          .format({'Mortalidade' : '{0:,.2f}%'})
          .format({'Casos/100 mil habitantes' : '{0:,.2f}'})
          .highlight_max(color='lightgreen', subset=['Mortes', 'População 2019'])
          .highlight_min(color='#cd4f39', subset=['Mortes', 'População 2019'])
          .background_gradient(subset=['Casos'], cmap='PuRd')
          .background_gradient(subset=['Mortes'], cmap='Reds')
          .bar(color='#FFA07A', subset=['Mortalidade'], align='left')
          .bar(color='lightgreen', subset=['Casos/100 mil habitantes'], align='left')
          .set_caption(f'COVID-19 por Estados - {datetime.datetime.strptime(dataAtual, "%Y-%m-%d").strftime("%d/%m/%Y")}'))
html
# Out:
# <style  type="text/css" >
#     #T_fe55812c_820d_11ea_aa72_0242ac1c0002 table {
#           border-collapse: collapse;
#     }    #T_fe55812c_820d_11ea_aa72_0242ac1c0002 th {
#           text-align: center;
#           width: 15%;
#     }    #T_fe55812c_820d_11ea_aa72_0242ac1c0002 td {
#           border: 1px solid black;
#           text-align: right;
#     }    #T_fe55812c_820d_11ea_aa72_0242ac1c0002row0_col0 {
#             background-color:  #f6f3f8;
#             color:  #000000;
#         }    #T_fe55812c_820d_11ea_aa72_0242ac1c0002row0_col1 {
#             : ;
#             : ;
#             background-color:  #fff4ef;
#             color:  #000000;
#         }    #T_fe55812c_820d_11ea_aa72_0242ac1c0002row0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A 26.3%, transparent 26.3%);
#         }    #T_fe55812c_820d_11ea_aa72_0242ac1c0002row0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 31.0%, transparent 31.0%);
#         }    #T_fe55812c_820d_11ea_aa72_0242ac1c0002row1_col0 {
#             background-color:  #f6f3f9;
#             color:  #000000;
#         }    #T_fe55812c_820d_11ea_aa72_0242ac1c0002row1_col1 {
#             : ;
#             : ;
#             background-color:  #fff4ee;
#             color:  #000000;
#         }    #T_fe55812c_820d_11ea_aa72_0242ac1c0002row1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A 56.9%, transparent 56.9%);
#         }    #T_fe55812c_820d_11ea_aa72_0242ac1c0002row1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 4.1%, transparent 4.1%);
#         }    #T_fe55812c_820d_11ea_aa72_0242ac1c0002row2_col0 {
#             background-color:  #e6deee;
#             color:  #000000;
#         }    #T_fe55812c_820d_11ea_aa72_0242ac1c0002row2_col1 {
#             : ;
#             : ;
#             background-color:  #fdd5c4;
#             color:  #000000;
#         }    #T_fe55812c_820d_11ea_aa72_0242ac1c0002row2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A 65.2%, transparent 65.2%);
#         }    #T_fe55812c_820d_11ea_aa72_0242ac1c0002row2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 96.6%, transparent 96.6%);
#         }    #T_fe55812c_820d_11ea_aa72_0242ac1c0002row3_col0 {
#             background-color:  #f4f0f7;
#             color:  #000000;
#         }    #T_fe55812c_820d_11ea_aa72_0242ac1c0002row3_col1 {
#             : ;
#             : ;
#             background-color:  #fff4ee;
#             color:  #000000;
#         }    #T_fe55812c_820d_11ea_aa72_0242ac1c0002row3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A 10.5%, transparent 10.5%);
#         }    #T_fe55812c_820d_11ea_aa72_0242ac1c0002row3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 100.0%, transparent 100.0%);
#         }    #T_fe55812c_820d_11ea_aa72_0242ac1c0002row4_col0 {
#             background-color:  #ece7f2;
#             color:  #000000;
#         }    #T_fe55812c_820d_11ea_aa72_0242ac1c0002row4_col1 {
#             : ;
#             : ;
#             background-color:  #ffeee7;
#             color:  #000000;
#         }    #T_fe55812c_820d_11ea_aa72_0242ac1c0002row4_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A 18.1%, transparent 18.1%);
#         }    #T_fe55812c_820d_11ea_aa72_0242ac1c0002row4_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 13.2%, transparent 13.2%);
#         }    #T_fe55812c_820d_11ea_aa72_0242ac1c0002row5_col0 {
#             background-color:  #d9c4e0;
#             color:  #000000;
#         }    #T_fe55812c_820d_11ea_aa72_0242ac1c0002row5_col1 {
#             : ;
#             : ;
#             background-color:  #fdd0bc;
#             color:  #000000;
#         }    #T_fe55812c_820d_11ea_aa72_0242ac1c0002row5_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A 41.4%, transparent 41.4%);
#         }    #T_fe55812c_820d_11ea_aa72_0242ac1c0002row5_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 69.5%, transparent 69.5%);
#         }    #T_fe55812c_820d_11ea_aa72_0242ac1c0002row6_col0 {
#             background-color:  #f0ecf5;
#             color:  #000000;
#         }    #T_fe55812c_820d_11ea_aa72_0242ac1c0002row6_col1 {
#             : ;
#             : ;
#             background-color:  #fff2eb;
#             color:  #000000;
#         }    #T_fe55812c_820d_11ea_aa72_0242ac1c0002row6_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A 15.2%, transparent 15.2%);
#         }    #T_fe55812c_820d_11ea_aa72_0242ac1c0002row6_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 53.8%, transparent 53.8%);
#         }    #T_fe55812c_820d_11ea_aa72_0242ac1c0002row7_col0 {
#             background-color:  #ede9f3;
#             color:  #000000;
#         }    #T_fe55812c_820d_11ea_aa72_0242ac1c0002row7_col1 {
#             : ;
#             : ;
#             background-color:  #fff0e9;
#             color:  #000000;
#         }    #T_fe55812c_820d_11ea_aa72_0242ac1c0002row7_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A 12.6%, transparent 12.6%);
#         }    #T_fe55812c_820d_11ea_aa72_0242ac1c0002row7_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 55.9%, transparent 55.9%);
#         }    #T_fe55812c_820d_11ea_aa72_0242ac1c0002row8_col0 {
#             background-color:  #f4f0f7;
#             color:  #000000;
#         }    #T_fe55812c_820d_11ea_aa72_0242ac1c0002row8_col1 {
#             : ;
#             : ;
#             background-color:  #fff2ec;
#             color:  #000000;
#         }    #T_fe55812c_820d_11ea_aa72_0242ac1c0002row8_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A 31.2%, transparent 31.2%);
#         }    #T_fe55812c_820d_11ea_aa72_0242ac1c0002row8_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 7.3%, transparent 7.3%);
#         }    #T_fe55812c_820d_11ea_aa72_0242ac1c0002row9_col0 {
#             background-color:  #ece7f2;
#             color:  #000000;
#         }    #T_fe55812c_820d_11ea_aa72_0242ac1c0002row9_col1 {
#             : ;
#             : ;
#             background-color:  #ffede5;
#             color:  #000000;
#         }    #T_fe55812c_820d_11ea_aa72_0242ac1c0002row9_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A 24.1%, transparent 24.1%);
#         }    #T_fe55812c_820d_11ea_aa72_0242ac1c0002row9_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 33.0%, transparent 33.0%);
#         }    #T_fe55812c_820d_11ea_aa72_0242ac1c0002row10_col0 {
#             background-color:  #ede9f3;
#             color:  #000000;
#         }    #T_fe55812c_820d_11ea_aa72_0242ac1c0002row10_col1 {
#             : ;
#             : ;
#             background-color:  #ffefe8;
#             color:  #000000;
#         }    #T_fe55812c_820d_11ea_aa72_0242ac1c0002row10_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A 20.8%, transparent 20.8%);
#         }    #T_fe55812c_820d_11ea_aa72_0242ac1c0002row10_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 6
