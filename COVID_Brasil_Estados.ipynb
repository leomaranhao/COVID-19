# %% [markdown]
# <a href="https://colab.research.google.com/github/leomaranhao/COVID-19/blob/master/COVID_Brasil_Estados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import pandas.io.formats.format as pf
import datetime

# %%
df = pd.read_csv('https://brasil.io/dataset/covid19/caso?format=csv')

estados = df.loc[df.place_type=='state',['date','state','confirmed','deaths','is_last', 'estimated_population_2019']]

# %%
ultimas = estados.loc[estados.is_last==True, :]
ultimas.index = ultimas['state']
dataAtual = ultimas.iloc[0,0]
ultimas = ultimas.iloc[:, [2,3,5]]

ultimas.index.names = ['Estados']
ultimas.columns = ['Casos', 'Mortes', 'População 2019']

ultimas['Mortalidade'] = ultimas['Mortes']/ultimas['Casos'] * 100
ultimas['Casos/100 mil habitantes'] = ultimas['Casos'] / ultimas['População 2019'] * 100000

styles = [
    dict(selector="table", props=[("border-collapse", "collapse")]),
    dict(selector="th", props=[("text-align", "center"),
                               ("width", "15%")]),
    dict(selector="td", props=[("border", "1px solid black"),
                               #("width", "10%"),
                               ("text-align", "right")])
]

html = (ultimas.style.set_table_styles(styles)
          .format({'Casos' : '{0:,.0f}'})
          .format({'Mortes' : '{0:,.0f}'})
          .format({'População 2019' : '{0:,.0f}'})
          .format({'Mortalidade' : '{0:,.2f}%'})
          .format({'Casos/100 mil habitantes' : '{0:,.2f}'})
          .highlight_max(color='lightgreen', subset=['Mortes', 'População 2019'])
          .highlight_min(color='#cd4f39', subset=['Mortes', 'População 2019'])
          .background_gradient(subset=['Casos'], cmap='PuRd')
          .background_gradient(subset=['Mortes'], cmap='Reds')
          .bar(color='#FFA07A', subset=['Mortalidade'], align='left')
          .bar(color='lightgreen', subset=['Casos/100 mil habitantes'], align='left')
          .set_caption(f'COVID-19 por Estados - {datetime.datetime.strptime(dataAtual, "%Y-%m-%d").strftime("%d/%m/%Y")}'))
html
# Out:
# <style  type="text/css" >
#     #T_ef8d13de_85ec_11ea_9bbd_0242ac1c0002 table {
#           border-collapse: collapse;
#     }    #T_ef8d13de_85ec_11ea_9bbd_0242ac1c0002 th {
#           text-align: center;
#           width: 15%;
#     }    #T_ef8d13de_85ec_11ea_9bbd_0242ac1c0002 td {
#           border: 1px solid black;
#           text-align: right;
#     }    #T_ef8d13de_85ec_11ea_9bbd_0242ac1c0002row0_col0 {
#             background-color:  #f5f2f8;
#             color:  #000000;
#         }    #T_ef8d13de_85ec_11ea_9bbd_0242ac1c0002row0_col1 {
#             : ;
#             : ;
#             background-color:  #fff3ed;
#             color:  #000000;
#         }    #T_ef8d13de_85ec_11ea_9bbd_0242ac1c0002row0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A 55.6%, transparent 55.6%);
#         }    #T_ef8d13de_85ec_11ea_9bbd_0242ac1c0002row0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 10.4%, transparent 10.4%);
#         }    #T_ef8d13de_85ec_11ea_9bbd_0242ac1c0002row1_col0 {
#             background-color:  #e0d3e8;
#             color:  #000000;
#         }    #T_ef8d13de_85ec_11ea_9bbd_0242ac1c0002row1_col1 {
#             : ;
#             : ;
#             background-color:  #fdd2bf;
#             color:  #000000;
#         }    #T_ef8d13de_85ec_11ea_9bbd_0242ac1c0002row1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A 68.3%, transparent 68.3%);
#         }    #T_ef8d13de_85ec_11ea_9bbd_0242ac1c0002row1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 100.0%, transparent 100.0%);
#         }    #T_ef8d13de_85ec_11ea_9bbd_0242ac1c0002row2_col0 {
#             background-color:  #f3f0f7;
#             color:  #000000;
#         }    #T_ef8d13de_85ec_11ea_9bbd_0242ac1c0002row2_col1 {
#             : ;
#             : ;
#             background-color:  #fff4ee;
#             color:  #000000;
#         }    #T_ef8d13de_85ec_11ea_9bbd_0242ac1c0002row2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A 18.0%, transparent 18.0%);
#         }    #T_ef8d13de_85ec_11ea_9bbd_0242ac1c0002row2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 93.9%, transparent 93.9%);
#         }    #T_ef8d13de_85ec_11ea_9bbd_0242ac1c0002row3_col0 {
#             background-color:  #e9e4f1;
#             color:  #000000;
#         }    #T_ef8d13de_85ec_11ea_9bbd_0242ac1c0002row3_col1 {
#             : ;
#             : ;
#             background-color:  #ffeee6;
#             color:  #000000;
#         }    #T_ef8d13de_85ec_11ea_9bbd_0242ac1c0002row3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A 22.6%, transparent 22.6%);
#         }    #T_ef8d13de_85ec_11ea_9bbd_0242ac1c0002row3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 14.4%, transparent 14.4%);
#         }    #T_ef8d13de_85ec_11ea_9bbd_0242ac1c0002row4_col0 {
#             background-color:  #d1b1d6;
#             color:  #000000;
#         }    #T_ef8d13de_85ec_11ea_9bbd_0242ac1c0002row4_col1 {
#             : ;
#             : ;
#             background-color:  #fdcab5;
#             color:  #000000;
#         }    #T_ef8d13de_85ec_11ea_9bbd_0242ac1c0002row4_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A 45.8%, transparent 45.8%);
#         }    #T_ef8d13de_85ec_11ea_9bbd_0242ac1c0002row4_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 72.8%, transparent 72.8%);
#         }    #T_ef8d13de_85ec_11ea_9bbd_0242ac1c0002row5_col0 {
#             background-color:  #f0ecf5;
#             color:  #000000;
#         }    #T_ef8d13de_85ec_11ea_9bbd_0242ac1c0002row5_col1 {
#             : ;
#             : ;
#             background-color:  #fff2ec;
#             color:  #000000;
#         }    #T_ef8d13de_85ec_11ea_9bbd_0242ac1c0002row5_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A 16.1%, transparent 16.1%);
#         }    #T_ef8d13de_85ec_11ea_9bbd_0242ac1c0002row5_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 43.9%, transparent 43.9%);
#         }    #T_ef8d13de_85ec_11ea_9bbd_0242ac1c0002row6_col0 {
#             background-color:  #ece7f2;
#             color:  #000000;
#         }    #T_ef8d13de_85ec_11ea_9bbd_0242ac1c0002row6_col1 {
#             : ;
#             : ;
#             background-color:  #fff0e9;
#             color:  #000000;
#         }    #T_ef8d13de_85ec_11ea_9bbd_0242ac1c0002row6_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A 18.8%, transparent 18.8%);
#         }    #T_ef8d13de_85ec_11ea_9bbd_0242ac1c0002row6_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 49.9%, transparent 49.9%);
#         }    #T_ef8d13de_85ec_11ea_9bbd_0242ac1c0002row7_col0 {
#             background-color:  #f4f0f7;
#             color:  #000000;
#         }    #T_ef8d13de_85ec_11ea_9bbd_0242ac1c0002row7_col1 {
#             : ;
#             : ;
#             background-color:  #fff2ec;
#             color:  #000000;
#         }    #T_ef8d13de_85ec_11ea_9bbd_0242ac1c0002row7_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A 39.1%, transparent 39.1%);
#         }    #T_ef8d13de_85ec_11ea_9bbd_0242ac1c0002row7_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 5.6%, transparent 5.6%);
#         }    #T_ef8d13de_85ec_11ea_9bbd_0242ac1c0002row8_col0 {
#             background-color:  #e8e3f0;
#             color:  #000000;
#         }    #T_ef8d13de_85ec_11ea_9bbd_0242ac1c0002row8_col1 {
#             : ;
#             : ;
#             background-color:  #feeae1;
#             color:  #000000;
#         }    #T_ef8d13de_85ec_11ea_9bbd_0242ac1c0002row8_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A 33.7%, transparent 33.7%);
#         }    #T_ef8d13de_85ec_11ea_9bbd_0242ac1c0002row8_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 37.1%, transparent 37.1%);
#         }    #T_ef8d13de_85ec_11ea_9bbd_0242ac1c0002row9_col0 {
#             background-color:  #ede9f3;
#             color:  #000000;
#         }    #T_ef8d13de_85ec_11ea_9bbd_0242ac1c0002row9_col1 {
#             : ;
#             : ;
#             background-color:  #ffefe8;
#             color:  #000000;
#         }    #T_ef8d13de_85ec_11ea_9bbd_0242ac1c0002row9_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A 27.8%, transparent 27.8%);
#         }    #T_ef8d13de_85ec_11ea_9bbd_0242ac1c0002row9_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 5.1%, transparent 5.1%);
#         }    #T_ef8d13de_85ec_11ea_9bbd_0242ac1c0002row10_col0 {
#             background-color:  #f6f3f8;
#             color:  #000000;
#         }    #T_ef8d13de_85ec_11ea_9bbd_0242ac1c0002row10_col1 {
#             : ;
#             : ;
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_ef8d13de_85ec_11ea_9bbd_0242ac1c0002row10_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A 26.5%, transparent 26.5%);
#         }    #T_ef8d13de_85ec_11ea_9bbd_0242ac1c0002row10_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 5

# %%
totalizacao = ultimas.loc[: , ['Casos', 'Mortes', 'População 2019'] ].sum()
totalizacao['Mortalidade(%)'] = totalizacao['Mortes']/totalizacao['Casos'] * 100
totalizacao['Casos/100 mil habitantes'] = totalizacao['Casos'] / totalizacao['População 2019'] * 100000

totalizacao = pd.DataFrame(totalizacao).T
totalizacao.index = [dataAtual]
totalizacao
# Out:
#               Casos  Mortes  ...  Mortalidade(%)  Casos/100 mil habitantes
# 2020-04-23  49242.0  3270.0  ...        6.640673                 23.432155
#
# [1 rows x 5 columns]
